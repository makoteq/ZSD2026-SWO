# %%
# !pip install -U ultralytics
# Out:
# Requirement already satisfied: ultralytics in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (8.4.32)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (2.33.1)
# Requirement already satisfied: scipy>=1.4.1 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (1.39.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.3 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from polars>=0.20.0->ultralytics) (1.39.3)
# Requirement already satisfied: six>=1.5 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: sympy==1.13.1 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\marek\.conda\envs\yolo-gpu\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
import ultralytics
print(f"Ultralytics version: {ultralytics.__version__}")
import torch
import cv2
import numpy as np
from ultralytics import YOLO
import os
from PIL import Image
from torchvision import transforms
from IPython.display import display, clear_output
# Out:
# Ultralytics version: 8.4.21

# %%
model = YOLO('yolov8n.pt')
video_path = r"data\traffic.mp4"
cap = cv2.VideoCapture(video_path)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 22.7MB/s 0.3s.2s<0.3s9s

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
try:
    while cap.isOpened():
        success, frame = cap.read()
        if not success:
            break

        # 2. Wykonywanie predykcji bezpośrednio na GPU
        # Ustawiamy device=0 (indeks karty) zamiast zmiennej tekstowej, to czasem pomaga
        results = model.predict(
            source=frame, 
            conf=0.3, 
            verbose=False, 
            classes=[2, 3, 5, 7], 
            device=0 if device == 'cuda' else 'cpu'
        )

        annotated_frame = results[0].plot()
        annotated_frame_rgb = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(annotated_frame_rgb)

        clear_output(wait=True)
        display(img)

except KeyboardInterrupt:
    print("Przerwano ręcznie.")

finally:
    cap.release()
    cv2.destroyAllWindows()
