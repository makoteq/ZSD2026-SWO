# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow


load_dotenv()

api_key = os.getenv("ROBOFLOW_API_KEY")

if not api_key:
    raise ValueError("APIKEY not found")

# Inicjalizacja Roboflow
rf = Roboflow(api_key=api_key)

# Pobieranie projektu (używamy v19 i poprawnej nazwy formatu yolo26)
project = rf.workspace("archie-junio-dxv5t").project("car-detection-model-bwjpb")
dataset = project.version(19).download("yolo26")

print(f"Sukces! Dane pobrane do: {dataset.location}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Sukces! Dane pobrane do: z:\Documents\Programs\zsd_2026\model_training\Car-Detection-Model-19

# %%
from ultralytics import YOLO


model = YOLO("yolo26n.pt")

model.train(
    data=f"{dataset.location}/data.yaml", 
    epochs=50, 
    imgsz=640,
    name="yolo_car",  
    save=True,             
    save_period=10          
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 873.7KB/s 6.2ss<0.1s3s4s
# Ultralytics 8.4.21  Python-3.11.14 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=z:\Documents\Programs\zsd_2026\model_training\Car-Detection-Model-19/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo_car, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=\\192.168.0.237\Storage\admin\files\Documents\Programs\zsd_2026\model_training\runs\detect\yolo_car, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\kulak\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 1.1MB/s 0.7s 0.7s<0.0s3s
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    246246  ultralytics.nn.modules.head.Detect           [13, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,508,870 parameters, 2,508,870 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 1.30.1 ms, read: 9.23.7 MB/s, size: 59.2 KB)
# train: Scanning \\192.168.0.237\Storage\admin\files\Documents\Programs\zsd_2026\model_training\Car-Detection-Model-19\train\labels... 4569 images, 51 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4569/4569 273.0it/s 16.7s0.1s
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\dataset.py:168, in YOLODataset.get_labels(self)
#     167 try:
# --> 168     cache, exists = load_dataset_cache_file(cache_path), True  # attempt to load a *.cache file
#     169     assert cache["version"] == DATASET_CACHE_VERSION  # matches current version
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\utils.py:798, in load_dataset_cache_file(path)
#     797 gc.disable()  # reduce pickle load time https://github.com/ultralytics/ultralytics/pull/1585
# --> 798 cache = np.load(str(path), allow_pickle=True).item()  # load dict
#     799 gc.enable()
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\numpy\lib\_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\192.168.0.237\\Storage\\admin\\files\\Documents\\Programs\\zsd_2026\\model_training\\Car-Detection-Model-19\\train\\labels.cache'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 # 1. Załaduj model
#       4 model = YOLO("yolo26n.pt")
# ----> 6 model.train(
#       7     data=f"{dataset.location}/data.yaml",
#       8     epochs=50,
#       9     imgsz=640,
#      10     name="yolo_car",   # Zmienia nazwę folderu z konkretnym treningiem
#      11     save=True,               # (Domyślnie True) Czy w ogóle zapisywać wagi
#      12     save_period=10           # Zapisuje dodatkowy plik co X epok (np. co 10)
#      13 )
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\engine\model.py:777, in Model.train(self, trainer, **kwargs)
#     774     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     775     self.model = self.trainer.model
# --> 777 self.trainer.train()
#     778 # Update model and cfg after training
#     779 if RANK in {-1, 0}:
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\engine\trainer.py:244, in BaseTrainer.train(self)
#     241         ddp_cleanup(self, str(file))
#     243 else:
# --> 244     self._do_train()
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\engine\trainer.py:366, in BaseTrainer._do_train(self)
#     364 if self.world_size > 1:
#     365     self._setup_ddp()
# --> 366 self._setup_train()
#     368 nb = len(self.train_loader)  # number of batches
#     369 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\engine\trainer.py:348, in BaseTrainer._setup_train(self)
#     345 if self.batch_size < 1 and RANK == -1:  # single-GPU only, estimate best batch size
#     346     self.args.batch = self.batch_size = self.auto_batch()
# --> 348 self._build_train_pipeline()
#     349 self.validator = self.get_validator()
#     350 self.ema = ModelEMA(self.model)
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\engine\trainer.py:269, in BaseTrainer._build_train_pipeline(self)
#     267 """Build dataloaders, optimizer, and scheduler for current batch size."""
#     268 batch_size = self.batch_size // max(self.world_size, 1)
# --> 269 self.train_loader = self.get_dataloader(
#     270     self.data["train"], batch_size=batch_size, rank=LOCAL_RANK, mode="train"
#     271 )
#     272 # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
#     273 self.test_loader = self.get_dataloader(
#     274     self.data.get("val") or self.data.get("test"),
#     275     batch_size=batch_size if self.args.task == "obb" else batch_size * 2,
#     276     rank=LOCAL_RANK,
#     277     mode="val",
#     278 )
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\models\yolo\detect\train.py:93, in DetectionTrainer.get_dataloader(self, dataset_path, batch_size, rank, mode)
#      91 assert mode in {"train", "val"}, f"Mode must be 'train' or 'val', not {mode}."
#      92 with torch_distributed_zero_first(rank):  # init dataset *.cache only once if DDP
# ---> 93     dataset = self.build_dataset(dataset_path, mode, batch_size)
#      94 shuffle = mode == "train"
#      95 if getattr(dataset, "rect", False) and shuffle and not np.all(dataset.batch_shapes == dataset.batch_shapes[0]):
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\models\yolo\detect\train.py:77, in DetectionTrainer.build_dataset(self, img_path, mode, batch)
#      66 """Build YOLO Dataset for training or validation.
#      67
#      68 Args:
#    (...)     74     (Dataset): YOLO dataset object configured for the specified mode.
#      75 """
#      76 gs = max(int(unwrap_model(self.model).stride.max()), 32)
# ---> 77 return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, rect=mode == "val", stride=gs)
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\build.py:236, in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#     234 """Build and return a YOLO dataset based on configuration parameters."""
#     235 dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# --> 236 return dataset(
#     237     img_path=img_path,
#     238     imgsz=cfg.imgsz,
#     239     batch_size=batch,
#     240     augment=mode == "train",  # augmentation
#     241     hyp=cfg,  # TODO: probably add a get_hyps_from_cfg function
#     242     rect=cfg.rect or rect,  # rectangular batches
#     243     cache=cfg.cache or None,
#     244     single_cls=cfg.single_cls or False,
#     245     stride=stride,
#     246     pad=0.0 if mode == "train" else 0.5,
#     247     prefix=colorstr(f"{mode}: "),
#     248     task=cfg.task,
#     249     classes=cfg.classes,
#     250     data=data,
#     251     fraction=cfg.fraction if mode == "train" else 1.0,
#     252 )
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\dataset.py:88, in YOLODataset.__init__(self, data, task, *args, **kwargs)
#      86 self.data = data
#      87 assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 88 super().__init__(*args, channels=self.data.get("channels", 3), **kwargs)
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\base.py:118, in BaseDataset.__init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction, channels)
#     116 self.cv2_flag = cv2.IMREAD_GRAYSCALE if channels == 1 else cv2.IMREAD_COLOR
#     117 self.im_files = self.get_img_files(self.img_path)
# --> 118 self.labels = self.get_labels()
#     119 self.update_labels(include_class=classes)  # single_cls and include_class
#     120 self.ni = len(self.labels)  # number of images
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\dataset.py:172, in YOLODataset.get_labels(self)
#     170     assert cache["hash"] == get_hash(self.label_files + self.im_files)  # identical hash
#     171 except (FileNotFoundError, AssertionError, AttributeError, ModuleNotFoundError):
# --> 172     cache, exists = self.cache_labels(cache_path), False  # run cache ops
#     174 # Display cache
#     175 nf, nm, ne, nc, n = cache.pop("results")  # found, missing, empty, corrupt, total
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\dataset.py:151, in YOLODataset.cache_labels(self, path)
#     149 if nf == 0:
#     150     LOGGER.warning(f"{self.prefix}No labels found in {path}. {HELP_URL}")
# --> 151 x["hash"] = get_hash(self.label_files + self.im_files)
#     152 x["results"] = nf, nm, ne, nc, len(self.im_files)
#     153 x["msgs"] = msgs  # warnings
#
# File d:\miniconda3\envs\yolo-gpu\Lib\site-packages\ultralytics\data\utils.py:148, in get_hash(paths)
#     146 for p in paths:
#     147     try:
# --> 148         size += os.stat(p).st_size
#     149     except OSError:
#     150         continue
#
# KeyboardInterrupt:
